# %% [markdown]
# **10 Intro ANN**

# %% [markdown]
# # From Biological to Artificial Neurons

# %% [markdown]
# ## History

# %% [markdown]
# - ANN:1943 &rarr; Warren McCulloch, Walter Pitts
# - 1980 &rarr; new architectures & SVM &rarr; + performance &rarr; winter ANN

# %% [markdown]
# ## Biological Neurons

# %% [markdown]
# ## Logical Computation

# %% [markdown]
# - *identity function (A)*:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Perceptron

# %% [markdown]
# - Simplest ANN Architecture
#     - Based on TLU(threshold logic unit) &#8594; $z = w_1 x_1 + w_2 x_2 + \dots + w_n x_n + b = \mathbf{w}^\top \mathbf{x} + b$
#
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## MLP

# %% [markdown]
# ## Regression MLP

# %% [markdown]
# ## Classification MLP
